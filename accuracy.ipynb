# %%
import pandas as pd

# %%
import numpy as np

# %%
def read_csv_into_df(file_path):
    df = pd.read_csv(file_path)
    return df

# %%
result = read_csv_into_df("result_sgd.csv")
result
# Out:
#                                            customer_id  \
# 0    92d3aeb119b9cc817b19c82fd0e8e34cc16b72ab576aaf...
# 1    8f48180ed87acf89cc5e29b550a113a708b44ad0c41169...
# 2    c2171e81ae6d9b4625abb84b22efd446fd8defb1182503...
# 3    8ec01c91aa6e9232cfa56062af2400118454b3884e2d5c...
# 4    e070acfe693964c4a96c7264ec054b6812cf9233d2011e...
# ..                                                 ...
# 995  7afa150885f71394af074232477d98b591ec9b1e9d3e84...
# 996  3ab3b721f49da99886ec7139ff638d19d97fa9daf1e52d...
# 997  8a140b3f49a21b125fc6c8e83a09779b09e5458019683c...
# 998  5f479f6d3588ee0debb1e03f5cfca6c1c306e627797c85...
# 999  b088600baa54dc88c5be656a200f5a224c3cd2335279c7...
#
#                                             article_id
# 0    [882264001, 633590004, 579541007, 757915002, 4...
# 1    [757347005, 588423001, 589599001, 867205002, 6...
# 2    [783149001, 751530004, 403448008, 712173001, 6...
# 3    [687016002, 712173001, 610776033, 403448008, 9...
# ...

# %%
test = read_csv_into_df("transactions_train_processed.csv")
test
# Out:
#           Unnamed: 0       t_dat  \
# 0                  0  2018-09-20
# 1                  1  2018-09-20
# 2                  2  2018-09-20
# 3                  3  2018-09-20
# 4                  4  2018-09-20
# ...              ...         ...
# 31788319    31788319  2020-09-22
# 31788320    31788320  2020-09-22
# 31788321    31788321  2020-09-22
# 31788322    31788322  2020-09-22
# 31788323    31788323  2020-09-22
#
#                                                 customer_id  article_id  \
# 0         000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1         000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2         00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3         00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4         00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
# ...                                                     ...         ...
# ...

# %%
test_sim = test.drop(['price','sales_channel_id'], axis=1)

# %%
test_sim
# Out:
#           Unnamed: 0       t_dat  \
# 0                  0  2018-09-20
# 1                  1  2018-09-20
# 2                  2  2018-09-20
# 3                  3  2018-09-20
# 4                  4  2018-09-20
# ...              ...         ...
# 31788319    31788319  2020-09-22
# 31788320    31788320  2020-09-22
# 31788321    31788321  2020-09-22
# 31788322    31788322  2020-09-22
# 31788323    31788323  2020-09-22
#
#                                                 customer_id  article_id  week
# 0         000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001     0
# 1         000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023     0
# 2         00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004     0
# 3         00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003     0
# 4         00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004     0
# ...                                                     ...         ...   ...
# ...

# %%
len(result)
# Out:
# 1000

# %%
test_d = {}
for i in range(len(test_sim)):
    test_d[test_sim.customer_id[i]] = test_sim.article_id[i]
test_d
